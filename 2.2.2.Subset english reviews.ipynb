# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

import string
import nltk
#stemming
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag

# %% [markdown]
# ## Data import - processed reviews

# %%
dataset = pd.read_csv('./vienna_data/processed_reviews.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466660 entries, 0 to 466659
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   listing_id   466660 non-null  int64
#  1   reviewer_id  466660 non-null  int64
#  2   comments     466660 non-null  object
#  3   Compound     466660 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 14.2+ MB

# %% [markdown]
# ## Subset english reviews for word clouds

# %% [markdown]
# Count the total number of words per review and the english words per review into 2 separate columns

# %%
words = set(nltk.corpus.words.words())

length = len(dataset)
english_words = []
total_words = []

for i in range (0, length):
    count = 0
    totalcount = 0
    review = dataset.comments.values[i]
    #tokenize and lower review
    tokenized_review = nltk.wordpunct_tokenize(review)
    tokenized_review = [w.lower() for w in tokenized_review]
    
    #remove punctuation
    table = str.maketrans('', '', string.punctuation)
    stripped_review = [w.translate(table) for w in tokenized_review]
    stripped = [w for w in stripped_review if w.isalpha()]
    
    #POS-tag and lemmatize
    lemmaWords = []
    wordnet_lemmatizer = WordNetLemmatizer()
    for word,tag in pos_tag(stripped):
        wntag = tag[0].lower()
        wntag = wntag if wntag in ['a', 'r', 'n', 'v'] else None
        lemma = wordnet_lemmatizer.lemmatize(word, wntag) if wntag else word
        lemmaWords.append(lemma)
    
    for w in lemmaWords:
        totalcount +=1
        if w.lower()in words:
            count +=1
    english_words.append(count)
    total_words.append(totalcount)
    
dataset['english_words'] = np.array(english_words)
dataset['total_words'] = np.array(total_words)

# %%
with pd.option_context('display.max_colwidth', None): 
    print(dataset.tail(20))
# Out:
#         listing_id  reviewer_id  \
# 466640    42575315    336280355
# 466641    42575315    217364463
# 466642    42583867    175483145
# 466643    42631068    256961243
# 466644    42640682      1853439
# 466645    42642091    299008765
# 466646    42665072     14455623
# 466647    42665072      6036216
# 466648    42665072    196311212
# 466649    42666433    126455592
# 466650    42667250    141082281
# 466651    42667250     30923871
# 466652    42678136    287767126
# 466653    42689613    324408348
# 466654    42700746    177308173
# 466655    42705436      4005354
# 466656    42707880    143319370
# 466657    42741768     60936666
# 466658    42782957     12348831
# 466659    42822480    196565405
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               comments  \
# 466640                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Amazing apartment and very convenient location to get to the city center
# 466641                                                                                                                                                                                                                                                                                                                       Great space and very clean apartment  Easy access and check-in  The communication was very quick and easy  he also compromised with the check-out time  which was very nice of him   We would definitely come here again
# 466642                                                                                                                                                                                                                                                                                                                                                                                                                                  Amazing apartment  ten minutes walking to historic center  Transportation  is outstanding  Highly recommended
# 466643                                                                                                                                   The appartment is asoluteley lovely  super clean and well equipped  Everything is brand new  The location is perfect - Metro station accross the street  Lidl shop around the corner  parked my car directly in front of the appartment (free during weekends)  Highly recommend it  We even got a complimentary bottle of wine  which was great     And great value for the price   )  Totally recommend it
# 466644                                                                                                                                                                                                                                                                                                                                                                                                                                                               Euch erwartet ein top ausgestattetes Apartment in dem man sich sofort wohl fühlt
#
#         Compound  english_words  total_words
# 466640     58.59             12           12
# 466641     96.42             38           38
# 466642     87.18             13           13
# 466643     99.02             57           63
# 466644     20.23              4           13
# 466645      0.00              4           15
# 466646    -29.60             62           63
# 466647     97.05             84           90
# 466648     64.59             27           34
# 466649     88.05             10           10
# 466650     73.51              3           12
# 466651    -49.12              6           25
# 466652    -24.22             10           30
# 466653    -83.16              8           46
# 466654     66.81             11           12
# 466655     80.16             11           14
# 466656     55.74              7            7
# 466657     90.80             38           40
# 466658     98.82             88           94
# 466659      0.00              5           20

# %%
dataset['comments'][466648]
# Out:
# 'This accommodation is not so far from Vienna hbf station  Alexander is very kind and contacted us frequently  If you choose this accommodation  you can be got a rare experience   この宿はｳｨｰﾝ中央駅からそんなに遠く離れていません｡Alexanderさんは頻繁に連絡をくれるため､とても親切で安心できます｡この宿では少し珍しい体験をできるかもしれません '

# %%
dataset.head()
# Out:
#    listing_id  reviewer_id                                           comments  \
# 0       15883     30537860  If you need a clean  comfortable place to stay...
# 1       15883     37529754  It's so nice to be in the house  It's a peace ...
# 2       15883      3147341  A beautiful place  uniquely decorated showing ...
# 3       15883     29518067  Eine sehr schöne Unterkunft in einem privaten ...
# 4       15883     36016357  It was a very pleasant stay  Excellent locatio...
#
#    Compound  english_words  total_words
# 0     94.80             78           84
# 1     96.04             23           24
# 2     92.98             60           63
# 3      0.00              6           34
# 4     92.08             13           13

# %%
dataset[dataset['english_words']/dataset['total_words'] < 0.7 ]
# Out:
#         listing_id  reviewer_id  \
# 3            15883     29518067
# 7            15883     11338741
# 24           38768      2422768
# 26           38768      2526106
# 27           38768      3177185
# ...            ...          ...
# 466650    42667250    141082281
# 466651    42667250     30923871
# 466652    42678136    287767126
# 466653    42689613    324408348
# 466659    42822480    196565405
#
#                                                  comments  Compound  \
# 3       Eine sehr schöne Unterkunft in einem privaten ...      0.00
# 7       Der Aufenthalt bei Eva war zu meiner vollsten ...    -97.61
# 24      Sehr schöne Unterkunft  ruhig und doch zentral...    -59.94
# 26      la estancia en este apartamento por llamarlo d...    -83.16
# 27      Das Apartement ist perfekt für eine Städtereis...    -59.94
# ...                                                   ...       ...
# 466650  Super nette Gastgeberin  kleine feine Wohnung ...     73.51
# 466651  Leticia ist sehr nett und hilfsbereit  Die Woh...    -49.12
# 466652  Nette Kommunikation  unproblematischer Check-i...    -24.22
# 466653  Die Wohnung ist neu renoviert und sehr schön e...    -83.16
# 466659  Sehr zu empfehlen  Unkomplizierter Check-in  s...      0.00
#
#         english_words  total_words
# 3                   6           34
# 7                  17           70
# 24                  3           18
# 26                 80          186
# 27                 26           87
# ...               ...          ...
# 466650              3           12
# 466651              6           25
# 466652             10           30
# 466653              8           46
# 466659              5           20
#
# [156685 rows x 6 columns]

# %%
dataset.tail(20)
# Out:
#         listing_id  reviewer_id  \
# 466640    42575315    336280355
# 466641    42575315    217364463
# 466642    42583867    175483145
# 466643    42631068    256961243
# 466644    42640682      1853439
# 466645    42642091    299008765
# 466646    42665072     14455623
# 466647    42665072      6036216
# 466648    42665072    196311212
# 466649    42666433    126455592
# 466650    42667250    141082281
# 466651    42667250     30923871
# 466652    42678136    287767126
# 466653    42689613    324408348
# 466654    42700746    177308173
# 466655    42705436      4005354
# 466656    42707880    143319370
# 466657    42741768     60936666
# 466658    42782957     12348831
# 466659    42822480    196565405
#
#                                                  comments  Compound  \
# 466640  Amazing apartment and very convenient location...     58.59
# 466641  Great space and very clean apartment  Easy acc...     96.42
# 466642  Amazing apartment  ten minutes walking to hist...     87.18
# 466643  The appartment is asoluteley lovely  super cle...     99.02
# 466644  Euch erwartet ein top ausgestattetes Apartment...     20.23
# 466645  La estancia fue increíble  Nos dejaron cosas p...      0.00
# 466646  The apartment is clean and simple  You have to...    -29.60
# 466647  Very cute and great apartment  price vs value ...     97.05
# 466648  This accommodation is not so far from Vienna h...     64.59
# 466649    Me and my friend really liked it We loved it ❤️     88.05
# 466650  Super nette Gastgeberin  kleine feine Wohnung ...     73.51
# 466651  Leticia ist sehr nett und hilfsbereit  Die Woh...    -49.12
# 466652  Nette Kommunikation  unproblematischer Check-i...    -24.22
# 466653  Die Wohnung ist neu renoviert und sehr schön e...    -83.16
# 466654  Very nice people  They helped me with whatever...     66.81
# 466655  Very nice flat and great stay to do a Thermen-...     80.16
# 466656  Cute clean and quiet accommodation  Fantastic ...     55.74
# 466657  A very modern apartment in the middle of what ...     90.80
# 466658  The stay at Lisa   Dennis’s place was excellen...     98.82
# 466659  Sehr zu empfehlen  Unkomplizierter Check-in  s...      0.00
#
#         english_words  total_words
# 466640             12           12
# 466641             38           38
# 466642             13           13
# 466643             57           63
# 466644              4           13
# 466645              4           15
# 466646             62           63
# 466647             84           90
# 466648             27           34
# 466649             10           10
# 466650              3           12
# 466651              6           25
# 466652             10           30
# 466653              8           46
# 466654             11           12
# 466655             11           14
# 466656              7            7
# 466657             38           40
# 466658             88           94
# 466659              5           20

# %%
non_english = pd.DataFrame(dataset[dataset['english_words']/dataset['total_words'] < 0.7 ])

# %%
english = pd.DataFrame(dataset[dataset['english_words']/dataset['total_words'] >= 0.7])

# %%
huh = dataset[ (dataset['english_words']/dataset['total_words'] >= 0.7 ) & (dataset['english_words']/dataset['total_words'] <= 0.8 ) ]

# %%
len(huh)
# Out:
# 3988

# %%
huh.head()
# Out:
#      listing_id  reviewer_id  \
# 165       38768     65209029
# 210       38768     10590684
# 287       38768    179179808
# 369       40625     66422696
# 431       40625    122666236
#
#                                               comments  Compound  \
# 165  Hannes became very trustworthly and prompt co-...     69.69
# 210  Great place for an unposh stay in Vienna  Hann...     84.81
# 287  Hannes offers great appartments  well-located ...     87.77
# 369  Everything is perfectt  Thank you so much Ms  ...     36.12
# 431                          Ingela is amazingly kind      57.09
#
#      english_words  total_words
# 165             29           37
# 210             10           13
# 287             19           24
# 369              7            9
# 431              3            4

# %%
english.reset_index(drop = True, inplace=True)

# %%
with pd.option_context('display.max_colwidth', 200): 
    print(english.tail(10))
# Out:
#         listing_id  reviewer_id  \
# 309100    42631068    256961243
# 309101    42665072     14455623
# 309102    42665072      6036216
# 309103    42665072    196311212
# 309104    42666433    126455592
# 309105    42700746    177308173
# 309106    42705436      4005354
# 309107    42707880    143319370
# 309108    42741768     60936666
# 309109    42782957     12348831
#
#                                                                                                                                                                                                        comments  \
# 309100  The appartment is asoluteley lovely  super clean and well equipped  Everything is brand new  The location is perfect - Metro station accross the street  Lidl shop around the corner  parked my car ...
# 309101  The apartment is clean and simple  You have to pick the key up from the packet station  two stations far from the apartment  But it was no problem because Alexander described the exact way to the ...
# 309102  Very cute and great apartment  price vs value is the best you can find    mins to metro station in train station  there you can find cafes and Spar  Pros   cons in one thing auto-checking via lock...
# 309103  This accommodation is not so far from Vienna hbf station  Alexander is very kind and contacted us frequently  If you choose this accommodation  you can be got a rare experience   この宿はｳｨｰﾝ中央駅からそんなに...
# 309104                                                                                                                                                          Me and my friend really liked it We loved it ❤️
# 309105                                                                                                                             Very nice people  They helped me with whatever I needed   Highly recommended
# 309106                                                                                                                                    Very nice flat and great stay to do a Thermen-holiday in Therme Wien
# 309107                                                                                                                                                      Cute clean and quiet accommodation  Fantastic find
# 309108  A very modern apartment in the middle of what I consider to be the best district in Vienna  Would definetly recommend everyone staying here if you would like a high standards  a spacious apartment...
# 309109  The stay at Lisa   Dennis’s place was excellent  very comfortable and super clean  Lisa and Dennis are very friendly hosts and gave me a brochure with the top places to visit in Vienna  A bottle o...
#
#         Compound  english_words  total_words
# 309100     99.02             57           63
# 309101    -29.60             62           63
# 309102     97.05             84           90
# 309103     64.59             27           34
# 309104     88.05             10           10
# 309105     66.81             11           12
# 309106     80.16             11           14
# 309107     55.74              7            7
# 309108     90.80             38           40
# 309109     98.82             88           94

# %% [markdown]
# *As it can be seen, in the english dataset there is at least one comment in another language that the algorithm couldn't filter. One method could be filtering even further the english dataset and removing all words not recognized in english.*

# %%
english.comments[309103]
# Out:
# 'This accommodation is not so far from Vienna hbf station  Alexander is very kind and contacted us frequently  If you choose this accommodation  you can be got a rare experience   この宿はｳｨｰﾝ中央駅からそんなに遠く離れていません｡Alexanderさんは頻繁に連絡をくれるため､とても親切で安心できます｡この宿では少し珍しい体験をできるかもしれません '

# %%
english.iloc[309103, [4,5]]
# Out:
# english_words    27
# total_words      34
# Name: 309103, dtype: object

# %%
print(len(dataset))
print(len(english))
print(len(non_english))
# Out:
# 466660
# 309110
# 156685

# %%
english.to_csv('./vienna_data/englsih_reviews.csv', index = False)
